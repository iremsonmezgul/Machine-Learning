# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"C:/Users/Asus/Downloads/Mall_Customers.csv")

# %%
dataset.head(10)
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6
# 7           8  Female   23                  18                      94
# 8           9    Male   64                  19                       3
# 9          10  Female   30                  19                      72

# %%
dataset.shape
# Out:
# (200, 5)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
dataset.isnull().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
x = dataset.iloc[:, [3,4]].values

# %%
from sklearn.cluster import KMeans

# %%
wcss = []

for i in range (1,11):
    kmeans = KMeans(n_clusters =i , init ="k-means++", random_state=0)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15620\2038870907.py in <module>
#       3 for i in range (1,11):
#       4     kmeans = KMeans(n_clusters =i , init ="k-means++", random_state=0)
# ----> 5     kmeans.fit(x)
#       6     wcss.append(kmeans.inertia_)
#
# E:\anaconda\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#    1169         if self._algorithm == "full":
#    1170             kmeans_single = _kmeans_single_lloyd
# -> 1171             self._check_mkl_vcomp(X, X.shape[0])
#    1172         else:
#    1173             kmeans_single = _kmeans_single_elkan
#
# E:\anaconda\lib\site-packages\sklearn\cluster\_kmeans.py in _check_mkl_vcomp(self, X, n_samples)
#    1026         active_threads = int(np.ceil(n_samples / CHUNK_SIZE))
#    1027         if active_threads < self._n_threads:
# -> 1028             modules = threadpool_info()
#    1029             has_vcomp = "vcomp" in [module["prefix"] for module in modules]
#    1030             has_mkl = ("mkl", "intel") in [
#
# E:\anaconda\lib\site-packages\sklearn\utils\fixes.py in threadpool_info()
#     323         return controller.info()
#     324     else:
# --> 325         return threadpoolctl.threadpool_info()
#     326
#     327
#
# E:\anaconda\lib\site-packages\threadpoolctl.py in threadpool_info()
#     122
#     123
# --> 124 @lru_cache(maxsize=10000)
#     125 def _realpath(filepath):
#     126     """Small caching wrapper around os.path.realpath to limit system calls"""
#
# E:\anaconda\lib\site-packages\threadpoolctl.py in __init__(self, user_api, prefixes, modules)
#     338     isolation as these libraries do not offer thread-local APIs to configure the number
#     339     of threads to use in nested parallel calls.
# --> 340
#     341     Parameters
#     342     ----------
#
# E:\anaconda\lib\site-packages\threadpoolctl.py in _load_modules(self)
#     371
#     372     def __init__(self, limits=None, user_api=None):
# --> 373         super().__init__(ThreadpoolController(), limits=limits, user_api=user_api)
#     374
#     375     @classmethod
#
# E:\anaconda\lib\site-packages\threadpoolctl.py in _find_modules_with_enum_process_module_ex(self)
#     483
#     484             - If it is a dictionary `{{key: max_threads}}`, this function sets a
# --> 485               custom maximum number of threads for each `key` which can be either a
#     486               `user_api` or a `prefix` for a specific library.
#     487
#
# E:\anaconda\lib\site-packages\threadpoolctl.py in _make_module_from_path(self, filepath)
#     513     def wrap(self, *, limits=None, user_api=None):
#     514         """Change the maximal number of threads that can be used in thread pools.
# --> 515
#     516         This function returns an object that can be used as a decorator.
#     517
#
# E:\anaconda\lib\site-packages\threadpoolctl.py in __init__(self, filepath, prefix, user_api, internal_api)
#     604         if not hasattr(libc, "_dyld_image_count"):  # pragma: no cover
#     605             return []
# --> 606
#     607         n_dyld = libc._dyld_image_count()
#     608         libc._dyld_get_image_name.restype = ctypes.c_char_p
#
# E:\anaconda\lib\site-packages\threadpoolctl.py in get_version(self)
#     644             # module headers
#     645             while True:
# --> 646                 buf = (HMODULE * buf_count)()
#     647                 buf_size = ctypes.sizeof(buf)
#     648                 if not ps_api.EnumProcessModulesEx(
#
# AttributeError: 'NoneType' object has no attribute 'split'

# %%
plt.plot(range(1,11), wcss)
plt.title("elbow metod")
plt.xlabel("no of cluster")
plt.ylabel("wcss")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15620\1930593890.py in <module>
# ----> 1 plt.plot(range(1,11), wcss)
#       2 plt.title("elbow metod")
#       3 plt.xlabel("no of cluster")
#       4 plt.ylabel("wcss")
#       5 plt.show()
#
# E:\anaconda\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# E:\anaconda\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# E:\anaconda\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# E:\anaconda\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     496
#     497         if x.shape[0] != y.shape[0]:
# --> 498             raise ValueError(f"x and y must have same first dimension, but "
#     499                              f"have shapes {x.shape} and {y.shape}")
#     500         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (10,) and (0,)

# %%
kmeansmodel = KMeans(n_clusters=5, init="k-means++", random_state=0)
y_kmeans = kmeansmodel.fit_predict(x)

# %%
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s= 100, c ="red", label= "cluster 1")
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s= 100, c ="blue", label= "cluster 2")
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s= 100, c ="green", label= "cluster 3")
plt.scatter(x[y_kmeans == 3, 0], x[y_kmeans == 3, 1], s= 100, c ="cyan", label= "cluster 4")
plt.scatter(x[y_kmeans == 4, 0], x[y_kmeans == 4, 1], s= 100, c ="magenta", label= "cluster 5")

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c="yellow", label="centroids")
plt.title("müşteri klasları")
plt.xlabel("yıllık gelir")
plt.ylabel("harcama skoru")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15620\1055982014.py in <module>
#       5 plt.scatter(x[y_kmeans == 4, 0], x[y_kmeans == 4, 1], s= 100, c ="magenta", label= "cluster 5")
#       6
# ----> 7 plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c="yellow", label="centroids")
#       8 plt.title("müşteri klasları")
#       9 plt.xlabel("yıllık gelir")
#
# AttributeError: 'KMeans' object has no attribute 'cluster_centers_'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
x1 = np.random.normal(25,5,1000) 
y1 = np.random.normal(25,5,1000)

x2 = np.random.normal(55,5,1000)
y2 = np.random.normal(60,5,1000)

x3 = np.random.normal(55,5,1000)
y3 = np.random.normal(15,5,1000)

# %%
x = np.concatenate((x1,x2,x3),axis = 0) 
y = np.concatenate((y1,y2,y3),axis = 0)

# %%
dictionary = {"x":x,"y":y}

# %%
data = pd.DataFrame(dictionary)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       3000 non-null   float64
#  1   y       3000 non-null   float64
# dtypes: float64(2)
# memory usage: 47.0 KB

# %%
plt.scatter(x1,y1)               
plt.scatter(x2,y2)
plt.scatter(x3,y3)
plt.show()

# %%
plt.scatter(x1,y1,color = "black")
plt.scatter(x2,y2,color = "black")
plt.scatter(x3,y3,color = "black")
plt.show();

# %%
from sklearn.cluster import KMeans
wcss = []

for k in range(1,15):
    kmeans = KMeans(n_clusters=k) 
    kmeans.fit(data)             
    wcss.append(kmeans.inertia_)  
    
plt.plot(range(1,15),wcss)
plt.xlabel("number of k (cluster) value")
plt.ylabel("wcss")
plt.title("Elbow Method")
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15620\3752426670.py in <module>
#       4 for k in range(1,15):
#       5     kmeans = KMeans(n_clusters=k)
# ----> 6     kmeans.fit(data)
#       7     wcss.append(kmeans.inertia_)
#       8
#
# E:\anaconda\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#    1184
#    1185             # run a k-means once
# -> 1186             labels, inertia, centers, n_iter_ = kmeans_single(
#    1187                 X,
#    1188                 sample_weight,
#
# E:\anaconda\lib\site-packages\sklearn\cluster\_kmeans.py in _kmeans_single_lloyd(X, sample_weight, centers_init, max_iter, verbose, x_squared_norms, tol, n_threads)
#     623     # Threadpoolctl context to limit the number of threads in second level of
#     624     # nested parallelism (i.e. BLAS) to avoid oversubsciption.
# --> 625     with threadpool_limits(limits=1, user_api="blas"):
#     626         for i in range(max_iter):
#     627             lloyd_iter(
#
# E:\anaconda\lib\site-packages\sklearn\utils\fixes.py in threadpool_limits(limits, user_api)
#     312         return controller.limit(limits=limits, user_api=user_api)
#     313     else:
# --> 314         return threadpoolctl.threadpool_limits(limits=limits, user_api=user_api)
#     315
#     316
#
# E:\anaconda\lib\site-packages\threadpoolctl.py in __init__(self, limits, user_api)
#     169         return self
#     170
# --> 171     def __exit__(self, type, value, traceback):
#     172         self.restore_original_limits()
#     173
#
# E:\anaconda\lib\site-packages\threadpoolctl.py in _set_threadpool_limits(self)
#     266                 raise TypeError(
#     267                     "limits must either be an int, a list, a dict, or "
# --> 268                     f"'sequential_blas_under_openmp'. Got {type(limits)} instead"
#     269                 )
#     270
#
# E:\anaconda\lib\site-packages\threadpoolctl.py in __init__(self, user_api, prefixes, modules)
#     338     isolation as these libraries do not offer thread-local APIs to configure the number
#     339     of threads to use in nested parallel calls.
# --> 340
#     341     Parameters
#     342     ----------
#
# E:\anaconda\lib\site-packages\threadpoolctl.py in _load_modules(self)
#     371
#     372     def __init__(self, limits=None, user_api=None):
# --> 373         super().__init__(ThreadpoolController(), limits=limits, user_api=user_api)
#     374
#     375     @classmethod
#
# E:\anaconda\lib\site-packages\threadpoolctl.py in _find_modules_with_enum_process_module_ex(self)
#     483
#     484             - If it is a dictionary `{{key: max_threads}}`, this function sets a
# --> 485               custom maximum number of threads for each `key` which can be either a
#     486               `user_api` or a `prefix` for a specific library.
#     487
#
# E:\anaconda\lib\site-packages\threadpoolctl.py in _make_module_from_path(self, filepath)
#     513     def wrap(self, *, limits=None, user_api=None):
#     514         """Change the maximal number of threads that can be used in thread pools.
# --> 515
#     516         This function returns an object that can be used as a decorator.
#     517
#
# E:\anaconda\lib\site-packages\threadpoolctl.py in __init__(self, filepath, prefix, user_api, internal_api)
#     604         if not hasattr(libc, "_dyld_image_count"):  # pragma: no cover
#     605             return []
# --> 606
#     607         n_dyld = libc._dyld_image_count()
#     608         libc._dyld_get_image_name.restype = ctypes.c_char_p
#
# E:\anaconda\lib\site-packages\threadpoolctl.py in get_version(self)
#     644             # module headers
#     645             while True:
# --> 646                 buf = (HMODULE * buf_count)()
#     647                 buf_size = ctypes.sizeof(buf)
#     648                 if not ps_api.EnumProcessModulesEx(
#
# AttributeError: 'NoneType' object has no attribute 'split'

# %%
kmeans2 = KMeans(n_clusters=2)
clusters = kmeans2.fit_predict(data) 

data["label"] = clusters

plt.scatter(data.x[data.label == 0 ],data.y[data.label == 0],color = "red")   
plt.scatter(data.x[data.label == 1 ],data.y[data.label == 1],color = "green") 
plt.scatter(kmeans2.cluster_centers_[:,0],kmeans2.cluster_centers_[:,1],color = "blue") 
plt.show()

# %%
kmeans2 = KMeans(n_clusters=3)
clusters = kmeans2.fit_predict(data)

data["label"] = clusters

plt.scatter(data.x[data.label == 0 ],data.y[data.label == 0],color = "red")  
plt.scatter(data.x[data.label == 1 ],data.y[data.label == 1],color = "green") 
plt.scatter(data.x[data.label == 2 ],data.y[data.label == 2],color = "blue")  
plt.scatter(kmeans2.cluster_centers_[:,0],kmeans2.cluster_centers_[:,1],color = "yellow")  
plt.show()

# %%
kmeans2 = KMeans(n_clusters=4)
clusters = kmeans2.fit_predict(data)

data["label"] = clusters

plt.scatter(data.x[data.label == 0 ],data.y[data.label == 0],color = "red")    
plt.scatter(data.x[data.label == 1 ],data.y[data.label == 1],color = "green")  
plt.scatter(data.x[data.label == 2 ],data.y[data.label == 2],color = "blue")   
plt.scatter(data.x[data.label == 3 ],data.y[data.label == 3],color = "orange") 
plt.scatter(kmeans2.cluster_centers_[:,0],kmeans2.cluster_centers_[:,1],color = "yellow")
plt.show()

# %%
kmeans2 = KMeans(n_clusters=5)
clusters = kmeans2.fit_predict(data)

data["label"] = clusters

plt.scatter(data.x[data.label == 0 ],data.y[data.label == 0],color = "red")    
plt.scatter(data.x[data.label == 1 ],data.y[data.label == 1],color = "green")  
plt.scatter(data.x[data.label == 2 ],data.y[data.label == 2],color = "blue")  
plt.scatter(data.x[data.label == 4 ],data.y[data.label == 4],color = "purple") 
plt.scatter(kmeans2.cluster_centers_[:,0],kmeans2.cluster_centers_[:,1],color = "yellow") 
plt.show()
